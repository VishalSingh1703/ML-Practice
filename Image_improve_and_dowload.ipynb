# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalSingh1703/ML-Practice/blob/main/Image_improve_and_dowload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

from IPython import display
# display.set_matplotlib_formats('svg')
display.set_matplotlib_formats('svg')

# %%
x = np.linspace(.5, 5, 10)
y1 = np.log(x)
y2 = 2 - np.sqrt(x)

plt.plot(x, y1, "bo-", label = 'log')
plt.plot(x, y2, "rs-", label = 'sqrt')
plt.legend()
plt.savefig('test.png') # Go to the files section on the left and download the image
plt.savefig('test.pdf')
plt.show()
